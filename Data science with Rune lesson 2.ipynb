# %% [markdown]
# # Data science with Rune lesson/video 2

# %% [raw]
# We need to deal with data vizualization due to 3 aims:
# Data quality - explore data quality including identifying outliers,missing values
# Data exploration - understand data with visualisng ideas
# Data presentation - present results

# %% [raw]
# Data Vizualization

# %%
import pandas as pd

# %% [raw]
# fayl_adi=pd.read_csv('file url')

# %%
sample_dataset= pd.read_csv('C:/Users/ACER/OneDrive - Azerbaijan State Oil and Industry University/Desktop/Data Science with Rune/files/sample_corr.csv')

# %%
sample_dataset.head()
# Out:
#           x         y
# 0  1.105722  1.320945
# 1  1.158193  1.480131
# 2  1.068022  1.173479
# 3  1.131291  1.294706
# 4  1.125997  1.293024

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [raw]
# To create scatter plot
# fayl_adi.plot.satter(x='x',y='y')
# Dinaqlarin icinde olan x ve y column adlaridir

# %%
# create a scatter plot to determine is data coreelated or not 
sample_dataset.plot.scatter(x='x',y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
data=pd.read_csv('C:/Users/ACER/OneDrive - Azerbaijan State Oil and Industry University/Desktop/Data Science with Rune/files/sample_height.csv')

# %%
data.head()
# Out:
#        height
# 0  129.150282
# 1  163.277930
# 2  173.965641
# 3  168.933825
# 4  171.075462

# %%
data.columns
# Out:
# Index(['height'], dtype='object')

# %%
# checking missing data 
data.isna().any()
# Out:
# height    False
# dtype: bool

# %%
data.isnull().any()
# Out:
# height    False
# dtype: bool

# %% [raw]
# To create histogram
# fayl_adi.plot.hist()

# %%
# we can observe the distribution of data 
data.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# show us specific values which height is less than 50 
data[data['height']<50]
# Out:
#       height
# 17  1.913196
# 22  1.629159
# 23  1.753424
# 27  1.854795
# 50  1.914587
# 60  1.642295
# 73  1.804588
# 82  1.573621
# 91  1.550227
# 94  1.660700
# 97  1.675962
# 98  1.712382

# %%
data[data['height']>125]
# Out:
#         height
# 0   129.150282
# 1   163.277930
# 2   173.965641
# 3   168.933825
# 4   171.075462
# ..         ...
# 92  203.475711
# 93  182.149262
# 95  173.809723
# 96  189.045440
# 99  164.930814
#
# [88 rows x 1 columns]

# %%
data_1=pd.read_csv('C:/Users/ACER/OneDrive - Azerbaijan State Oil and Industry University/Desktop/Data Science with Rune/files/sample_age.csv')

# %%
data_1.head()
# Out:
#          age
# 0  30.175921
# 1  32.002551
# 2  44.518393
# 3  56.247751
# 4  33.111986

# %%
data_1.columns
# Out:
# Index(['age'], dtype='object')

# %%
data_1.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data_1.isna().any()
# Out:
# age    False
# dtype: bool

# %%
data_1.isnull().any()
# Out:
# age    False
# dtype: bool

# %% [raw]
# Butun lazimli statistik deyerlere birlikde baxmaq istedikde
# fayl_adi.describe()

# %%
#This code part gives us import and basic statistics of our dataset
# count, mean,standart deviation,minimum,maximum,quartiles
data_1.describe()
# Out:
#               age
# count  100.000000
# mean    42.305997
# std     29.229478
# min     18.273781
# 25%     31.871113
# 50%     39.376896
# 75%     47.779303
# max    314.000000

# %%
data_1.mean()
# Out:
# age    42.305997
# dtype: float64

# %%
data_1.std()
# Out:
# age    29.229478
# dtype: float64

# %%
data_1[data_1['age']>100]
# Out:
#       age
# 31  314.0

# %% [raw]
# Data Exploration

# %%
# idleri ve ya index columns(hansi ki datanin ilk sutununda gelir ve columnun sayini gosterir) aradan qaldirmaq ucun datani import ederken index_col=0 yaza bilerik
data_bank=pd.read_csv('C:/Users/ACER/OneDrive - Azerbaijan State Oil and Industry University/Desktop/Data Science with Rune/files/WorldBank-ATM.CO2E.PC_DS2.csv',index_col=0)

# %%
data_bank
# Out:
#              ABW       AFE       AFG       AFW       AGO       ALB       AND  \
# Year
# 1960  204.631696  0.906060  0.046057  0.090880  0.100835  1.258195       NaN
# 1961  208.837879  0.922474  0.053589  0.095283  0.082204  1.374186       NaN
# 1962  226.081890  0.930816  0.073721  0.096612  0.210533  1.439956       NaN
# 1963  214.785217  0.940570  0.074161  0.112376  0.202739  1.181681       NaN
# 1964  207.626699  0.996033  0.086174  0.133258  0.213562  1.111742       NaN
# 1965  185.213644  1.047280  0.101285  0.184803  0.205891  1.166099       NaN
# 1966  172.158729  1.033908  0.107399  0.193676  0.268937  1.333055       NaN
# 1967  210.819017  1.052204  0.123409  0.189305  0.172096  1.363746       NaN
# 1968  194.917536  1.079727  0.115142  0.143989  0.289702  1.519551       NaN
# 1969  253.544574  1.104632  0.086510  0.202129  0.480199  1.558968       NaN
# 1970  281.962316  1.123261  0.149651  0.302643  0.608224  1.753240       NaN
# ...

# %%
data_bank.head(10)
# Out:
#              ABW       AFE       AFG       AFW       AGO       ALB  AND  \
# Year
# 1960  204.631696  0.906060  0.046057  0.090880  0.100835  1.258195  NaN
# 1961  208.837879  0.922474  0.053589  0.095283  0.082204  1.374186  NaN
# 1962  226.081890  0.930816  0.073721  0.096612  0.210533  1.439956  NaN
# 1963  214.785217  0.940570  0.074161  0.112376  0.202739  1.181681  NaN
# 1964  207.626699  0.996033  0.086174  0.133258  0.213562  1.111742  NaN
# 1965  185.213644  1.047280  0.101285  0.184803  0.205891  1.166099  NaN
# 1966  172.158729  1.033908  0.107399  0.193676  0.268937  1.333055  NaN
# 1967  210.819017  1.052204  0.123409  0.189305  0.172096  1.363746  NaN
# 1968  194.917536  1.079727  0.115142  0.143989  0.289702  1.519551  NaN
# 1969  253.544574  1.104632  0.086510  0.202129  0.480199  1.558968  NaN
#
#            ARB         ARE       ARG  ...  VIR       VNM       VUT       WLD  \
# Year                                  ...
# ...

# %%
data_bank.columns
# Out:
# Index(['ABW', 'AFE', 'AFG', 'AFW', 'AGO', 'ALB', 'AND', 'ARB', 'ARE', 'ARG',
#        ...
#        'VIR', 'VNM', 'VUT', 'WLD', 'WSM', 'XKX', 'YEM', 'ZAF', 'ZMB', 'ZWE'],
#       dtype='object', length=266)

# %%
data_bank.isnull().any()
# Out:
# ABW     True
# AFE    False
# AFG    False
# AFW    False
# AGO    False
#        ...
# XKX     True
# YEM    False
# ZAF    False
# ZMB     True
# ZWE     True
# Length: 266, dtype: bool

# %%
data_bank.isna().any()
# Out:
# ABW     True
# AFE    False
# AFG    False
# AFW    False
# AGO    False
#        ...
# XKX     True
# YEM    False
# ZAF    False
# ZMB     True
# ZWE     True
# Length: 266, dtype: bool

# %% [raw]
# Correlationa baxmaq ucun
# fayl_adi.corr()

# %%
data_bank.corr()
# Out:
#           ABW       AFE       AFG       AFW       AGO       ALB       AND  \
# ABW  1.000000 -0.453351 -0.502958 -0.180877 -0.020925 -0.367901       NaN
# AFE -0.453351  1.000000  0.466669  0.402718 -0.184936  0.845522 -0.330496
# AFG -0.502958  0.466669  1.000000  0.352672  0.322833  0.591890 -0.754110
# AFW -0.180877  0.402718  0.352672  1.000000  0.535558  0.351148 -0.355787
# AGO -0.020925 -0.184936  0.322833  0.535558  1.000000 -0.045108 -0.657879
# ..        ...       ...       ...       ...       ...       ...       ...
# XKX       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# YEM -0.619561 -0.357308  0.067972  0.382559  0.757588 -0.394054  0.023232
# ZAF -0.545527  0.818084  0.636601  0.575304  0.287952  0.738641 -0.581636
# ZMB  0.572760  0.287794 -0.047252 -0.508005 -0.627351  0.283306 -0.433457
# ZWE -0.139282  0.333933 -0.062881  0.033947 -0.696369  0.150780  0.489735
#
#           ARB       ARE       ARG  ...  VIR       VNM       VUT       WLD  \
# ...

# %%
data_bank.corr()["ZWE"]
# Out:
# ABW   -0.139282
# AFE    0.333933
# AFG   -0.062881
# AFW    0.033947
# AGO   -0.696369
#          ...
# XKX         NaN
# YEM   -0.549881
# ZAF   -0.157057
# ZMB    0.382014
# ZWE    1.000000
# Name: ZWE, Length: 266, dtype: float64

# %%
data_bank.dtypes
# Out:
# ABW    float64
# AFE    float64
# AFG    float64
# AFW    float64
# AGO    float64
#         ...
# XKX    float64
# YEM    float64
# ZAF    float64
# ZMB    float64
# ZWE    float64
# Length: 266, dtype: object

# %%
data_bank.describe()
# Out:
#               ABW        AFE        AFG        AFW        AGO        ALB  \
# count   30.000000  59.000000  59.000000  59.000000  59.000000  59.000000
# mean   184.079829   1.089405   0.149382   0.440692   0.687540   1.660433
# std     84.724762   0.157525   0.085583   0.147548   0.329161   0.643504
# min      2.868274   0.900399   0.037055   0.090880   0.082204   0.470098
# 25%    169.081608   0.971170   0.073941   0.443857   0.476051   1.258155
# 50%    199.774616   1.033908   0.149651   0.476438   0.640966   1.572251
# 75%    232.217652   1.188124   0.207444   0.515941   0.912209   2.001541
# max    360.853233   1.431964   0.407074   0.648273   1.285365   2.898209
#
#              AND        ARB         ARE        ARG  ...  VIR        VNM  \
# count  29.000000  59.000000   59.000000  59.000000  ...  0.0  59.000000
# mean    6.778152   2.923164   30.416576   3.544621  ...  NaN   0.716099
# std     0.688945   1.089531   20.916706   0.512579  ...  NaN   0.652798
# ...

# %%
data_bank['USA'].plot(title='Amount of CO2 gas in USA',xlabel='Year',ylabel='CO2 degree',figsize=(15,6))
# Out:
# <AxesSubplot:title={'center':'Amount of CO2 gas in USA'}, xlabel='Year', ylabel='CO2 degree'>

# %%
data_bank[['USA','WLD']].plot(ylim=0) # ylim=0 yazanda vizualizationda tesvirim 0-dan baslasin isteyirem demekdir
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
data_bank[['USA','DNK']].plot(ylim=0,figsize=(15,5)) # figsize stretchs plot and help us to compare more easily and effectively
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [raw]
# Plot qurmaq ucun fayl_adi[['column1','column2']].plot(ylim=0)

# %%
data_bank[['DNK','ABW']].plot(ylim=0,figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [raw]
# Barplot qurmaq ucun fayl_adi['column'].plot.bar(icine parametrler yazmaq olar)
# Iki columnun deyerlerini muqayise etmek ucun bar plot quranda fayl_adi[['column1','column2']].plot.bar()

# %%
# barplot
data_bank['USA'].plot.bar(figsize=(25,10),color='purple')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#fayli import ederken qoydugum ad['column_adi'].plot.bar()
#plot ucun elave parameterler yazmaq olar mes title,xlabel,ylabel,figsize=()
data_bank[['USA','DNK']].plot.bar(title='Barplot shows differences',ylabel='Frequency',figsize=(20,10))
# Out:
# <AxesSubplot:title={'center':'Barplot shows differences'}, xlabel='Year', ylabel='Frequency'>

# %% [raw]
# X oxunda verilmis columnun mueyyen deyer araligininn tesviri lazim olanda
# fay_adi[['column1','column2']].loc[baslangic deyer:son deyer].plot.bar()

# %%
# create barplot with location 
data_bank[['USA','DNK']].loc[2000:].plot.bar(figsize=(20,10)) # meselen burada 2000-ci ilden sonra sona qeder olan datalarin barplotunu verir
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
data_bank[['USA','DNK']].loc[2000:2007].plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
data_bank['USA'].plot.hist(figsize=(20,10),color='green') # bins=10
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [raw]
# To create data frame
# data - keyword kimidir
# index - keyword tiplidir
# pd- it represents pandas
# data_frame=pd.Series(data = [vermek istediyin deyerler ve ya melumatlar], index = [vermek istediyin column adlari]

# %%
#We create a data frame with using Pandas 
data_frame=pd.Series(data=[10,13,28,57,80],index=['Country1','Country2','Country3','Country4','Country5'])
data_frame
# Out:
# Country1    10
# Country2    13
# Country3    28
# Country4    57
# Country5    80
# dtype: int64

# %%
data_frame_2=pd.Series(data=['Physics','Maths','Statistics','Programming','Data science'],index=['labelname_1','labelname2','labelname3','lablename_4','labelname5'])
data_frame_2
# Out:
# labelname_1         Physics
# labelname2            Maths
# labelname3       Statistics
# lablename_4     Programming
# labelname5     Data science
# dtype: object

# %% [raw]
# To create a pie-chart
# name_of_data_frame.plot.pie(we can write all parametrs inside of here)
# We must pay attention that data part must be integer otherwise we will face error because both of them cannot be strings,'names'

# %%
# Create a pie chart
data_frame.plot.pie(title='Distribution of countries',ylabel='Category names',figsize=(15,10))
# Out:
# <AxesSubplot:title={'center':'Distribution of countries'}, ylabel='Category names'>

# %%
(data_bank['DNK']<10).value_counts() # Danimarka columnunda 10-dan kicik deyerlerin sayini gosterir
# Out:
# False    35
# True     24
# Name: DNK, dtype: int64

# %%
(data_bank['DNK']<10).value_counts().plot.pie(ylabel='Denmark',figsize=(10,4),colors=['r','g'],labels=['Bigger than 10','Lesser than 10'],autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Denmark'>

# %%
data_new=pd.read_csv('C:/Users/ACER/OneDrive - Azerbaijan State Oil and Industry University/Desktop/Data Science with Rune/files/co2_gdp_per_capita.csv',index_col=0)

# %%
data_new
# Out:
#      CO2 per capita  GDP per capita
# AFE        0.933541     1507.861055
# AFG        0.200151      568.827927
# AFW        0.515544     1834.366604
# AGO        0.887380     3595.106667
# ALB        1.939732     4433.741739
# ..              ...             ...
# WSM        1.631588     4297.910383
# YEM        0.326682     1290.925239
# ZAF        7.496645     5639.901997
# ZMB        0.446065     1368.600235
# ZWE        0.849793     1509.523735
#
# [233 rows x 2 columns]

# %%
data_new.head()
# Out:
#      CO2 per capita  GDP per capita
# AFE        0.933541     1507.861055
# AFG        0.200151      568.827927
# AFW        0.515544     1834.366604
# AGO        0.887380     3595.106667
# ALB        1.939732     4433.741739

# %%
data_new.plot.scatter(x='CO2 per capita',y='GDP per capita')
# Out:
# <AxesSubplot:xlabel='CO2 per capita', ylabel='GDP per capita'>

# %%
data_new.corr()
# Out:
#                 CO2 per capita  GDP per capita
# CO2 per capita        1.000000        0.633178
# GDP per capita        0.633178        1.000000

# %%
data_world=pd.read_csv('C:/Users/ACER/OneDrive - Azerbaijan State Oil and Industry University/Desktop/Data Science with Rune/files/WorldBank-ATM.CO2E.PC_DS2.csv',index_col=0)

# %%
data_world.head()
# Out:
#              ABW       AFE       AFG       AFW       AGO       ALB  AND  \
# Year
# 1960  204.631696  0.906060  0.046057  0.090880  0.100835  1.258195  NaN
# 1961  208.837879  0.922474  0.053589  0.095283  0.082204  1.374186  NaN
# 1962  226.081890  0.930816  0.073721  0.096612  0.210533  1.439956  NaN
# 1963  214.785217  0.940570  0.074161  0.112376  0.202739  1.181681  NaN
# 1964  207.626699  0.996033  0.086174  0.133258  0.213562  1.111742  NaN
#
#            ARB       ARE       ARG  ...  VIR       VNM       VUT       WLD  \
# Year                                ...
# 1960  0.609268  0.119037  2.383343  ...  NaN  0.181947       NaN  3.121158
# 1961  0.662618  0.109136  2.458551  ...  NaN  0.183099       NaN  3.068090
# 1962  0.727117  0.163542  2.538447  ...  NaN  0.217694  0.595002  3.114839
# 1963  0.853116  0.175833  2.330685  ...  NaN  0.196997  0.471849  3.221195
# 1964  0.972381  0.132815  2.553442  ...  NaN  0.209870  0.864427  3.324046
#
# ...

# %%
data_world.columns
# Out:
# Index(['ABW', 'AFE', 'AFG', 'AFW', 'AGO', 'ALB', 'AND', 'ARB', 'ARE', 'ARG',
#        ...
#        'VIR', 'VNM', 'VUT', 'WLD', 'WSM', 'XKX', 'YEM', 'ZAF', 'ZMB', 'ZWE'],
#       dtype='object', length=266)

# %%
data_world.loc[2017].describe()
# Out:
# count    239.000000
# mean       4.154185
# std        4.575980
# min        0.028010
# 25%        0.851900
# 50%        2.667119
# 75%        6.158644
# max       32.179371
# Name: 2017, dtype: float64

# %%
data_world.loc[2017]['USA']
# Out:
# 14.8058824221278

# %%
ax=data_world.loc[2017].plot.hist(facecolor='green')
ax.set_xlabel('CO2 per capita')
ax.set_ylabel('Number of countries')
ax.annotate('USA', xy=(15,5),xytext=(15,30),
           arrowprops=dict(arrowstyle='->',
                          connectionstyle="arc3"))
# Out:
# Text(15, 30, 'USA')

# %%
# To get general information about dataset 
data_world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59 entries, 1960 to 2018
# Columns: 266 entries, ABW to ZWE
# dtypes: float64(266)
# memory usage: 125.1 KB

# %% [raw]
# To deal with null or missing values which are given in dataset

# %%
data_world.isnull().any()
# Out:
# ABW     True
# AFE    False
# AFG    False
# AFW    False
# AGO    False
#        ...
# XKX     True
# YEM    False
# ZAF    False
# ZMB     True
# ZWE     True
# Length: 266, dtype: bool

# %%
data_world.isnull().sum()
# Out:
# ABW    29
# AFE     0
# AFG     0
# AFW     0
# AGO     0
#        ..
# XKX    59
# YEM     0
# ZAF     0
# ZMB     4
# ZWE     4
# Length: 266, dtype: int64

# %%
data_world.isnull().sum().plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [raw]
# To clean data removing columns which have null or missing values is one of the way. However it is not the best,appropriate way. Sometimes it works

# %%
clean_data = data_world.dropna(axis="columns")

# %%
data_world.columns
# Out:
# Index(['ABW', 'AFE', 'AFG', 'AFW', 'AGO', 'ALB', 'AND', 'ARB', 'ARE', 'ARG',
#        ...
#        'VIR', 'VNM', 'VUT', 'WLD', 'WSM', 'XKX', 'YEM', 'ZAF', 'ZMB', 'ZWE'],
#       dtype='object', length=266)

# %%
len(data_world.columns)
# Out:
# 266

# %%
len(clean_data.columns)
# Out:
# 191

# %%
data_world.shape
# Out:
# (59, 266)

# %% [raw]
# In some cases we need to calculate changes durin the specific period of time
# in CO2 case we can write the amount of CO2 in 2017 - the amount of CO2 in 1997 and divide to the amount of CO2 in 2017
# As a result we calculated the percentages of development during 20 years and we can visualize it in different ways
